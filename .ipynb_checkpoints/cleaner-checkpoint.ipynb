# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
style.use('ggplot')

# %%
# the data is in a seperate directory so it will 
# only run once read in data set check the size
df = pd.read_excel("../Data/ICTO_Datasets/ICTO_Datasets.xlsx")
df.shape
# Out:
# (22529, 10)

# %%
# only run once converts to csv in same directory
df.to_csv("../Data/ICTO_Datasets/ICTO_Datasets.csv")

# %%
# create a data frame of half of the random samples in the csv
df = pd.read_csv("../Data/ICTO_Datasets/ICTO_Datasets.csv").sample(frac=0.5)
df.shape

# %%
# number of rows should be half of original data set
df.shape
# Out:
# (11264, 11)

# %%
df = df.dropna() # drop null values in the data set
df.shape
# Out:
# (9745, 11)

# %%
#plotting the data
plt.scatter(df['StartDate'], df['MinistryMonthlyBudgetAmount'], label='Start', 
            color='k', marker="X")
plt.scatter(df['EndDate'], df['MinistryMonthlyBudgetAmount'], label='End',
           color='r', marker="*")
plt.title("Start and End Date budget Amounts")
plt.xlabel("Year")
plt.ylabel("Budget")
plt.legend()
plt.show()

# %%
df.describe()
# Out:
#               Index  MemberAccountId  MinistryMonthlyBudgetAmount  \
# count   9745.000000     9.745000e+03                  9745.000000
# mean   11150.118933     4.022587e+18                  4655.543663
# std     6537.728139     1.320642e+15                  1807.350769
# min        0.000000     4.018520e+18                    44.000000
# 25%     5435.000000     4.022470e+18                  3314.000000
# 50%    11174.000000     4.023340e+18                  4573.000000
# 75%    16862.000000     4.023350e+18                  5922.000000
# max    22526.000000     4.023400e+18                 13925.000000
#
#        Number_of_Household_Members
# count                  9745.000000
# mean                      1.852642
# std                       0.360793
# min                       1.000000
# 25%                       2.000000
# 50%                       2.000000
# 75%                       2.000000
# max                       3.000000

# %%
df.head()
# Out:
#        Index  MemberAccountId  MinistryMonthlyBudgetAmount  StartDate  \
# 15839  15839     4.023350e+18                         4765   1/1/2014
# 2876    2876     4.022460e+18                         3556   3/1/2013
# 9911    9911     4.023340e+18                         3468  11/1/2009
# 10803  10803     4.023340e+18                         6796   7/1/2011
# 20810  20810     4.023390e+18                         7589  10/1/2014
#
#           EndDate Marital_Status  Number_of_Household_Members         City  \
# 15839  12/31/2014        Married                            2  Lake Forest
# 2876    2/28/2014        Married                            2       Waxhaw
# 9911   10/31/2010        Married                            2   Long Beach
# 10803   4/30/2012        Married                            2     Yorktown
# 20810   7/31/2015        Married                            2    Ketchikan
#
#       State  PostalCode                   Country
# 15839    CA       92630  United States of America
# 2876     NC       28173  United States of America
# 9911     CA       90808  United States of America
# 10803    IN  47396-1104  United States of America
# 20810    AK       99950  United States of America

# %%
# drop unecessary columns
df = df.drop(['MemberAccountId', 'Index'], axis=1)
df.head()
# Out:
#        MinistryMonthlyBudgetAmount  StartDate     EndDate Marital_Status  \
# 15839                         4765   1/1/2014  12/31/2014        Married
# 2876                          3556   3/1/2013   2/28/2014        Married
# 9911                          3468  11/1/2009  10/31/2010        Married
# 10803                         6796   7/1/2011   4/30/2012        Married
# 20810                         7589  10/1/2014   7/31/2015        Married
#
#        Number_of_Household_Members         City State  PostalCode  \
# 15839                            2  Lake Forest    CA       92630
# 2876                             2       Waxhaw    NC       28173
# 9911                             2   Long Beach    CA       90808
# 10803                            2     Yorktown    IN  47396-1104
# 20810                            2    Ketchikan    AK       99950
#
#                         Country
# 15839  United States of America
# 2876   United States of America
# 9911   United States of America
# 10803  United States of America
# 20810  United States of America

# %%
# delete all rows for where column country is not "United States of America"
indexNames = df[ df['Country'] != 'United States of America'].index
df.drop(indexNames, inplace=True)

# %% [markdown]
# df['Country'] != 'United States of America' - creates boolean series depending on values of Country
# Index(['Country'], dtype='object') - gives index object containing index label where
# Country does not have value 'United States of America'
#  df.drop( df[df['Country'] != 'United States of America'].index, inplace=True) - deletes all rows
# that are not equal to United States of America in Country column

# %%
df.shape
# Out:
# (8932, 9)

# %% [markdown]
# Read out the column of the data set that has the zip codes
# We will manipulate it so that the zip codes are the proper data type for visualization
# Dealing with zip codes,
# Our zip codes aren't numerical, they are categories for each area

# %%
# second way to read in data from csv,
# uses same random sampling technique to read in data
# but we are changing the data types of the zip code from numerical to categorical
df1 = pd.io.parsers.read_csv('../Data/ICTO_Datasets/ICTO_Datasets.csv', dtype={'zip': pd.Categorical})
