# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../../Data/ICTO_Datasets/features_ICTO_Datasets.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  MinistryMonthlyBudgetAmount  StartDate  \
# 0           0             1                         5485   3/1/2013
# 1           1             2                         4454  11/1/2011
# 2           2             3                          767   1/1/2013
# 3           3             4                         6368   7/1/2015
# 4           4             5                         1919   8/1/2011
#
#       EndDate Marital_Status  Number_of_Household_Members          City State  \
# 0  12/31/2013        Married                            2      Erlanger    KY
# 1   4/30/2012        Married                            2  Spanish Fort    AL
# 2  12/31/2013         Single                            1     Lexington    KY
# 3   2/29/2016        Married                            2       Manheim    PA
# 4   7/31/2012       Divorced                            1  Jacksonville    FL
#
#    PostalCode                   Country  Coded_Marital_Status  End_Yr  \
# 0       41018  United States of America                   2.0  2013.0
# 1       36527  United States of America                   2.0  2012.0
# 2       40517  United States of America                   4.0  2013.0
# 3       17545  United States of America                   2.0  2016.0
# 4  32258-5434  United States of America                   1.0  2012.0
#
#    Start_Yr  End_Mnth  Start_Mnth
# 0    2013.0      12.0         3.0
# 1    2011.0       4.0        11.0
# 2    2013.0      12.0         1.0
# 3    2015.0       2.0         7.0
# 4    2011.0       7.0         8.0

# %%
df_out = pd.read_csv('../../Data/OutsideData/us-zip-code-latitude-and-longitude.csv')
df_out.head()
# Out:
#      Zip      City State   Latitude  Longitude  Timezone  \
# 0  71937      Cove    AR  34.398483  -94.39398        -6
# 1  72044  Edgemont    AR  35.624351  -92.16056        -6
# 2  56171  Sherburn    MN  43.660847  -94.74357        -6
# 3  49430    Lamont    MI  43.010337  -85.89754        -5
# 4  52585  Richland    IA  41.194129  -91.98027        -6
#
#    Daylight savings time flag              geopoint
# 0                           1  34.398483, -94.39398
# 1                           1  35.624351, -92.16056
# 2                           1  43.660847, -94.74357
# 3                           1  43.010337, -85.89754
# 4                           1  41.194129, -91.98027

# %%
geo_coords = df_out['geopoint']
geo_coords
# Out:
# 0         34.398483, -94.39398
# 1         35.624351, -92.16056
# 2         43.660847, -94.74357
# 3         43.010337, -85.89754
# 4         41.194129, -91.98027
#                  ...
# 43186     40.055411, -75.13793
# 43187     31.334062, -83.59971
# 43188     42.005815, -85.46428
# 43189      28.852564, -82.0321
# 43190    42.614852, -73.970812
# Name: geopoint, Length: 43191, dtype: object

# %%
split_coords=geo_coords.str.split(',')

# %%
sliced_coords = pd.DataFrame(geo_coords.str.split(',',1).tolist(),
                             columns = ['latitude','longitude'])

# %%
sliced_coords
# Out:
#         latitude    longitude
# 0      34.398483    -94.39398
# 1      35.624351    -92.16056
# 2      43.660847    -94.74357
# 3      43.010337    -85.89754
# 4      41.194129    -91.98027
# ...          ...          ...
# 43186  40.055411    -75.13793
# 43187  31.334062    -83.59971
# 43188  42.005815    -85.46428
# 43189  28.852564     -82.0321
# 43190  42.614852   -73.970812
#
# [43191 rows x 2 columns]

# %%
frames = [df_out, sliced_coords]
df_new = pd.concat(frames, axis=1)
df_new
# Out:
#          Zip          City State   Latitude  Longitude  Timezone  \
# 0      71937          Cove    AR  34.398483 -94.393980        -6
# 1      72044      Edgemont    AR  35.624351 -92.160560        -6
# 2      56171      Sherburn    MN  43.660847 -94.743570        -6
# 3      49430        Lamont    MI  43.010337 -85.897540        -5
# 4      52585      Richland    IA  41.194129 -91.980270        -6
# ...      ...           ...   ...        ...        ...       ...
# 43186  19126  Philadelphia    PA  40.055411 -75.137930        -5
# 43187  31775         Omega    GA  31.334062 -83.599710        -5
# 43188  49072        Mendon    MI  42.005815 -85.464280        -5
# 43189  34785      Wildwood    FL  28.852564 -82.032100        -5
# 43190  12248        Albany    NY  42.614852 -73.970812        -5
#
#        Daylight savings time flag               geopoint   latitude  \
# 0                               1   34.398483, -94.39398  34.398483
# 1                               1   35.624351, -92.16056  35.624351
# 2                               1   43.660847, -94.74357  43.660847
# 3                               1   43.010337, -85.89754  43.010337
# 4                               1   41.194129, -91.98027  41.194129
# ...                           ...                    ...        ...
# 43186                           1   40.055411, -75.13793  40.055411
# 43187                           1   31.334062, -83.59971  31.334062
# 43188                           1   42.005815, -85.46428  42.005815
# 43189                           1    28.852564, -82.0321  28.852564
# 43190                           1  42.614852, -73.970812  42.614852
#
#          longitude
# 0        -94.39398
# 1        -92.16056
# 2        -94.74357
# 3        -85.89754
# 4        -91.98027
# ...            ...
# 43186    -75.13793
# 43187    -83.59971
# 43188    -85.46428
# 43189     -82.0321
# 43190   -73.970812
#
# [43191 rows x 10 columns]

# %%
df_new = df_new.drop(['latitude', 'longitude', 'Daylight savings time flag', 'Timezone'], axis=1)

# %%
df_new
# Out:
#          Zip          City State   Latitude  Longitude               geopoint
# 0      71937          Cove    AR  34.398483 -94.393980   34.398483, -94.39398
# 1      72044      Edgemont    AR  35.624351 -92.160560   35.624351, -92.16056
# 2      56171      Sherburn    MN  43.660847 -94.743570   43.660847, -94.74357
# 3      49430        Lamont    MI  43.010337 -85.897540   43.010337, -85.89754
# 4      52585      Richland    IA  41.194129 -91.980270   41.194129, -91.98027
# ...      ...           ...   ...        ...        ...                    ...
# 43186  19126  Philadelphia    PA  40.055411 -75.137930   40.055411, -75.13793
# 43187  31775         Omega    GA  31.334062 -83.599710   31.334062, -83.59971
# 43188  49072        Mendon    MI  42.005815 -85.464280   42.005815, -85.46428
# 43189  34785      Wildwood    FL  28.852564 -82.032100    28.852564, -82.0321
# 43190  12248        Albany    NY  42.614852 -73.970812  42.614852, -73.970812
#
# [43191 rows x 6 columns]

# %%
df_gcd = df_new.drop(['Zip','geopoint'], axis=1)
df_gcd.head()
# Out:
#        City State   Latitude  Longitude
# 0      Cove    AR  34.398483  -94.39398
# 1  Edgemont    AR  35.624351  -92.16056
# 2  Sherburn    MN  43.660847  -94.74357
# 3    Lamont    MI  43.010337  -85.89754
# 4  Richland    IA  41.194129  -91.98027

# %%
# map df_gcd to df using City and State

# %%
df_result = pd.merge(df, df_gcd, on=['City', 'State'])
df_result.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  MinistryMonthlyBudgetAmount StartDate  \
# 0           0             1                         5485  3/1/2013
# 1        1137          1138                         5756  2/1/2016
# 2        3783          3784                         5896  4/1/2016
# 3        3790          3791                         6277  6/1/2008
# 4        6731          6732                         6556  1/1/2005
#
#       EndDate Marital_Status  Number_of_Household_Members      City State  \
# 0  12/31/2013        Married                            2  Erlanger    KY
# 1   3/31/2016        Married                            2  Erlanger    KY
# 2   3/31/2017        Married                            2  Erlanger    KY
# 3   8/31/2009        Married                            2  Erlanger    KY
# 4   6/30/2005        Married                            2  Erlanger    KY
#
#   PostalCode                   Country  Coded_Marital_Status  End_Yr  \
# 0      41018  United States of America                   2.0  2013.0
# 1      41018  United States of America                   2.0  2016.0
# 2      41018  United States of America                   2.0  2017.0
# 3      41018  United States of America                   2.0  2009.0
# 4      41018  United States of America                   2.0  2005.0
#
#    Start_Yr  End_Mnth  Start_Mnth   Latitude  Longitude
# 0    2013.0      12.0         3.0  39.013755  -84.60229
# 1    2016.0       3.0         2.0  39.013755  -84.60229
# 2    2016.0       3.0         4.0  39.013755  -84.60229
# 3    2008.0       8.0         6.0  39.013755  -84.60229
# 4    2005.0       6.0         1.0  39.013755  -84.60229

# %%
cites = df_result['City']
states = df_result['State']
